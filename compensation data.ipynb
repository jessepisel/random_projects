# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_csv("C:\Users\jpisel\Downloads\distal_filtered_JRP.csv")
df=pd.DataFrame(data)

# %%
for i in range(1000):
    data.iloc[i].plot(color=plt.cm.copper(i/10))

# %%
data.shape[1]
# Out:
# 3678

# %%
balls=data.iloc[200]-data.iloc[0]
balls.plot()

# %%
blankDF=pd.DataFrame()
elevationDF=pd.DataFrame()
for i in range(10):
    for j in range(i):
        elevationDF[i]=np.where(data.iloc[j]>data.iloc[i],data.iloc[i],data.iloc[j])
        blankDF=blankDF.append(elevationDF)

# %%
blankDF.plot()

# %%
data.iloc[0:,4][:10]
# Out:
# 0    802.0
# 1    802.0
# 2    802.0
# 3    803.0
# 4    804.0
# 5    804.0
# 6    804.0
# 7    802.0
# 8    803.0
# 9    806.0
# Name: 8.02E+02.4, dtype: float64

# %%
data.iloc[0:,4][:10].plot()

# %%
yes[0,1]
# Out:
# 4
