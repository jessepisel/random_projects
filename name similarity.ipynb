# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib as plt
import jellyfish
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-dc902bc35764> in <module>()
#       3 import sklearn
#       4 import matplotlib as plt
# ----> 5 import jellyfish
#
# ImportError: No module named 'jellyfish'

# %%
data=pd.read_csv('C:/Users/jpisel/Downloads/output/NationalNames.csv')

# %%
dataf=pd.DataFrame(data)

# %%
dataf
# Out:
#               Id       Name  Year Gender  Count
# 0              1       Mary  1880      F   7065
# 1              2       Anna  1880      F   2604
# 2              3       Emma  1880      F   2003
# 3              4  Elizabeth  1880      F   1939
# 4              5     Minnie  1880      F   1746
# 5              6   Margaret  1880      F   1578
# 6              7        Ida  1880      F   1472
# 7              8      Alice  1880      F   1414
# 8              9     Bertha  1880      F   1320
# 9             10      Sarah  1880      F   1288
# 10            11      Annie  1880      F   1258
# 11            12      Clara  1880      F   1226
# 12            13       Ella  1880      F   1156
# 13            14   Florence  1880      F   1063
# 14            15       Cora  1880      F   1045
# 15            16     Martha  1880      F   1040
# 16            17      Laura  1880      F   1012
# 17            18     Nellie  1880      F    995
# 18            19      Grace  1880      F    982
# ...

# %%
sel=dataf[(dataf["Year"]==1880) & (dataf["Gender"]=="F")]

# %%
sel.plot(x="Year")
# Out:
# C:\Users\jpisel\AppData\Local\Continuum\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2562: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=1880.0, right=1880.0
#   'left=%s, right=%s') % (left, right))

# %%
# %matplotlib inline

# %%
for i in range(0,10):
    print(sel["Name"][i])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ecf29c5bb8b9> in <module>()
#       1 for i in range(0,10):
# ----> 2     print(string.sel["Name"][i])
#       3
#
# NameError: name 'string' is not defined

# %%
sel["Name"][1]
# Out:
# 'Anna'
